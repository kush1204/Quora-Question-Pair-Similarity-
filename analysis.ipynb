# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from subprocess import check_output
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import os
import gc
import re
from nltk.corpus import stopwords
# import distance
from nltk.stem import PorterStemmer
from bs4 import BeautifulSoup
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.express as px

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %% [markdown]
# ## Exploratory Data Analysis ##

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %% [markdown]
# Note : question 1 column has 1 null value & qusestion 2 column has 2 null values

# %%
df
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# ...        ...     ...     ...
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# ...

# %% [markdown]
# Distribution of data points among output classes

# %%
df.groupby('is_duplicate')["id"].count().plot.bar()
# Out:
# <Axes: xlabel='is_duplicate'>

# %% [markdown]
# Imbalance data class 0 has more datapoints compare to class 1

# %%
print('~> Total number of question pairs for training:\n   {}'.format(len(df)))
# Out:
# ~> Total number of question pairs for training:
#    404290

# %%
print('\n~> Question pairs are Similar (is_duplicate = 1):\n   {}%'.format(round(df['is_duplicate'].mean()*100, 2)))
print('~> Question pairs are not Similar (is_duplicate = 0):\n   {}%'.format(100 - round(df['is_duplicate'].mean()*100, 2)))
# Out:
# ~> Question pairs are Similar (is_duplicate = 1):
#    36.92%
# ~> Question pairs are not Similar (is_duplicate = 0):
#    63.08%

# %% [markdown]
# Number of unique Questions

# %%
qids=pd.Series(df['qid1'].tolist()+df['qid2'].tolist())
unique_qs=len(np.unique(qids))
qs_morethan_onetime=np.sum(qids.value_counts()>1)
 

print("Number of unique questions are : {}\n".format(unique_qs))
print("Number of unique questions that appear more than one time : {} ({}%) \n".format(qs_morethan_onetime,round(qs_morethan_onetime/unique_qs*100,2)))

print ('Max number of times a single question is repeated: {}\n'.format(max(qids.value_counts())))
# Out:
# Number of unique questions are : 537933
#
# Number of unique questions that appear more than one time : 111780 (20.78%)
#
# Max number of times a single question is repeated: 157

# %% [markdown]
# Note : 80 % of questions occur ony once

# %%
len(qids.unique())
# Out:
# 537933

# %%
x=["Unique Questions","Repeated Questions"]
y=[unique_qs,qs_morethan_onetime]

#create plot
colors = ['#1f77b4', '#ff7f0e'] 
plt.figure(figsize=(10,6))
plt.title("Plot representing unique and repeated Questions")
sns.barplot(x=x,y=y,palette=colors)
plt.xlabel('Question Type')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\ankus\AppData\Local\Temp\ipykernel_18440\4274120012.py:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# <h3> Checking for Duplicates </h3>

# %%
pair_duplicates = df[['qid1','qid2','is_duplicate']].groupby(['qid1','qid2']).count().reset_index()

print ("Number of duplicate questions",(pair_duplicates).shape[0] - df.shape[0])
# Out:
# Number of duplicate questions 0

# %%
plt.figure(figsize=(20,10))
plt.hist(qids.value_counts(),bins=160)       # give the counts of a question ..... how many times a question is occured
plt.yscale('log')
plt.title('Log-Histogram of question appearance counts')

plt.xlabel('Number of occurences of question')

plt.ylabel('Number of questions')

print ('Maximum number of times a single question is repeated: {}\n'.format(max(qids.value_counts())))
# Out:
# Maximum number of times a single question is repeated: 157

# %% [markdown]
# #### checking for null values

# %%
nan_rows=df[df.isnull().any(1)]
print(nan_rows)
# Out:
#             id    qid1    qid2                         question1  \
# 105780  105780  174363  174364    How can I develop android app?
# 201841  201841  303951  174364  How can I create an Android app?
# 363362  363362  493340  493341                               NaN
#
#                                                 question2  is_duplicate
# 105780                                                NaN             0
# 201841                                                NaN             0
# 363362  My Chinese name is Haichao Yu. What English na...             0

# %%
df=df.fillna('')

# %%
nan_rows=df[df.isnull().any(1)]
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [id, qid1, qid2, question1, question2, is_duplicate]
# Index: []

# %% [markdown]
# ## Basic Feature Extraction (Before Cleaning)
#
# Let us now construct a few features like:
#  - ____freq_qid1____ = Frequency of qid1's
#  - ____freq_qid2____ = Frequency of qid2's
#  - ____q1len____ = Length of q1
#  - ____q2len____ = Length of q2
#  - ____q1_n_words____ = Number of words in Question 1
#  - ____q2_n_words____ = Number of words in Question 2
#  - ____word_Common____ = (Number of common unique words in Question 1 and Question 2)  ---> higher the no of common words higher prob of duplicates
#  - ____word_Total____ =(Total num of words in Question 1 + Total num of words in Question 2)
#  - ____word_share____ = (word_common)/(word_Total)
#  - ____freq_q1+freq_q2____ = sum total of frequency of qid1 and qid2
#  - ____freq_q1-freq_q2____ = absolute difference of frequency of qid1 and qid2

# %%
if os.path.isfile('fe_without_preprocessing_train.csv'):
    df = pd.read_csv("fe_without_preprocessing_train.csv")
else:
    df['freq_qid1']=df.groupby('qid1')['qid1'].transform('count')   # give the count of qid1 (how many times qid1 is repeated)
    df['freq_qid2']=df.groupby('qid2')['qid2'].transform('count')   # give the count of qid2

    df['q1len'] = df['question1'].str.len()                         # character length of q1 ( how many characters are there in q1)
    df['q2len'] = df['question2'].str.len()                         # character length of q2

    df['q1_n_words'] = df['question1'].apply(lambda row: len(row.str.split(" ")))  # number of words in q1 (taking a row and spliting it by space and then taking the length of the split ie number of words)
    df['q2_n_words'] = df['question2'].apply(lambda row: len(row.str.split(" ")))

    def common_words(row):
        w1=set(map(lambda word: word.lower(),row['question1'].str.split(' ')))
        w2=set(map(lambda word: word.lower(),row['question2'].str.split(' ')))
        return 1* len(w1 & w2)
    df['common_words']=df.apply(common_words,axis=1)

    def total_words(row):
        w1=set(map(lambda word: word.lower(),row['question1'].str.split(' ')))
        w2=set(map(lambda word: word.lower(),row['question2'].str.split(' ')))
        return 1 * len(w1) + len(w2)
    df['total_words']=df.apply(total_words,axis=1)

    def word_share(row):   
        w1 = set(map(lambda word: word.lower(), row['question1'].str.split(" ")))
        w2 = set(map(lambda word: word.lower(), row['question2'].str.split(" ")))    
        return 1.0 * len(w1 & w2)/(len(w1) + len(w2))
    df['word_share'] = df.apply(word_share, axis=1)

    df['freq_q1+q2'] = df['freq_qid1']+df['freq_qid2']
    df['freq_q1-q2'] = abs(df['freq_qid1']-df['freq_qid2'])

    df.to_csv("fe_without_preprocessing_train.csv", index=False)

# %%
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  q1len  q2len  q1_n_words  q2_n_words  common_words  total_words  \
# ...

# %% [markdown]
# Analysis of Extracted Features

# %%
print ("Minimum length of the questions in question1 : " , min(df['q1_n_words']))

print ("Minimum length of the questions in question2 : " , min(df['q2_n_words']))

print ("Number of Questions with minimum length [question1] :", df[df['q1_n_words']== 1].shape[0])
print ("Number of Questions with minimum length [question2] :", df[df['q2_n_words']== 1].shape[0])
# Out:
# Minimum length of the questions in question1 :  1
# Minimum length of the questions in question2 :  1
# Number of Questions with minimum length [question1] : 67
# Number of Questions with minimum length [question2] : 24

# %% [markdown]
# Feature : Word_share

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
sns.violinplot(x='is_duplicate',y="word_share",data=df)

plt.subplot(1,2,2)
sns.histplot(df[df['is_duplicate'] == 1]['word_share'] , label = "1", color = 'red')
sns.histplot(df[df['is_duplicate'] == 0]['word_share'] , label = "0" , color = 'blue')

plt.show()

# %% [markdown]
# Feature : Common_words

# %%
plt.figure(figsize=(12, 8))

plt.subplot(1,2,1)
sns.violinplot(x = 'is_duplicate', y = 'common_words', data = df[0:])

plt.subplot(1,2,2)
sns.histplot(df[df['is_duplicate'] == 1.0]['common_words'][0:] , label = "1", color = 'red')
sns.histplot(df[df['is_duplicate'] == 0.0]['common_words'][0:] , label = "0" , color = 'blue' )
plt.show()

# %% [markdown]
# PreProcessing of Text/Data

# %%
# Removal of HTML Tags  ----> <br> <a> etc
# Removiing Puntuatuation   ----> . , ? ! etc
# Performing Stemming    ----> running, ran, run
# Removing Stopwords  ----> a, an, the, is, are etc
# Expanding Contractions   ----> don't -> do not

# %% [markdown]
# EDA : Advance Feature Extraction

# %% [markdown]
# - Token : you get a token on splitting a sentence by space
# - Word : A token that is not a stopword
